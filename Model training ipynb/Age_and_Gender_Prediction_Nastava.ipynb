# %% [markdown]
# #### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
# Out:
# 2.2.0

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.0'

# %%
import time

#starting time -> da izmjerimo koliko programu treba da se sav kod izvrši
begin = time.time()

# %% [markdown]
# #### Data Preprocessing

# %%
fldr="/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFace"

# %%
import os
files=os.listdir(fldr)

# %%
#prolazimo kroz svaku sliku i iz naziva uzimamo podatke o godinama i spolu(prvo broj u nazivu označava godine, a drugi spol)
#0- muško, 1-žensko
import cv2
ages=[]
genders=[]
images=[]

for fle in files:
  #iz slike uzimamo podatke i spremamo u polje
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)

  #učitavanje slike iz putanje kao polje piksela, promjena formata boje i rezising te spremanje u polje
  total=fldr+'/'+fle
  #print(total)
  image=cv2.imread(total)

  #iz dokumentacije: When the image file is read with the OpenCV function imread(), the order of colors is BGR
    #Therefore, if you want to use both the Pillow function and the OpenCV function, you need to convert BGR and RGB.
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image= cv2.resize(image,(48,48))
  images.append(image)

print("finished")
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FBF946596D8>
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FBF94659668>
# finished

# %%
''' visak 
for fle in files:
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)
'''

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(images[24])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA826F18C50>

# %%
print(ages[24])
print(genders[24])
# Out:
# 80
# 1

# %%
cv2_imshow(images[53])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA81D2BC780>

# %%
print(ages[53])
print(genders[53])
# Out:
# 80
# 1

# %%
import numpy as np
images_f=np.array(images)
genders_f=np.array(genders)
ages_f=np.array(ages)

# %%
np.save(fldr+'image.npy',images_f)
np.save(fldr+'gender.npy',genders_f)
np.save(fldr+'age.npy',ages_f)

# %%
#loadanje ako smo već jednom obradili
import numpy as np
genders_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFacegender2.npy')
images_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceimage2.npy')
ages_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceage2.npy')

# %% [markdown]
# Male = 0
# Female= 1

# %%
values, counts = np.unique(genders_f, return_counts=True)
print(counts)
# Out:
# [27153 18961]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male', 'Female']
values=[counts[0],counts[1]]
ax.bar(gender,values)
plt.show()

# %%
#vidimo da ima npr 1123 osoba s 1 godinom i 4 osobe za 116 godina
values, counts = np.unique(ages_f, return_counts=True)
print(counts)
# Out:
# [1123  720  459  452  367  351  324  454  363  289  229  312  289  312
#   334  405  334  478  306  518  558  698  755 1224 1129 2672 1261 1454
#  1281 1208  881 1314  780  997 1564 1187  951  815  738 1020  674  776
#   627  462  862  525  526  433  482  621  366  448  473  599  522  546
#   337  411  296  513  359  249  279  170  365  215  248  216  204  241
#   127  158  163  132  220  158  128  191  109  237   22   40   18   24
#   155   35   10   34   33   82    2   13    5    9   17    9   11    2
#     1    5    5    1    3    4]

# %%
#val=values.tolist()
cnt=counts.tolist()

# %%
#u bazi podataka najviše dvadesetogodišnjaka
plt.plot(counts)
plt.xlabel('ages')
plt.ylabel('distribution')
plt.show()

# %%
#pripremanje kategorija za varijablu Y
labels=[]

i=0
while i<len(ages_f):
  label=[]
  label.append([ages_f[i]])
  label.append([genders_f[i]])
  labels.append(label)
  i+=1

# %%
#normalizacija podataka
images_f_2=images_f/255

# %%
labels_f=np.array(labels)

# %%
images_f_2.shape
# Out:
# (46114, 48, 48, 3)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(images_f_2, labels_f,test_size=0.2)

# %%
#prvi element označava godine, drugi spol
Y_train[0:5]
# Out:
# array([[[ 9],
#         [ 0]],
#
#        [[44],
#         [ 1]],
#
#        [[ 9],
#         [ 0]],
#
#        [[ 6],
#         [ 0]],
#
#        [[21],
#         [ 0]]])

# %%
#pretvaranje iz oblika [[[godina], [spol]],...] u oblik [[godina],[godina],...][[spol], [spol],...]] dakle iz toga da u svaki array sadrži godinu i spol u oblik da jedan array sadrži godinu a drugi spol
Y_train_2=[Y_train[:,1],Y_train[:,0]]
Y_test_2=[Y_test[:,1],Y_test[:,0]]

# %%
Y_train_2
# Out:
# [array([[0],
#         [1],
#         [0],
#         ...,
#         [1],
#         [1],
#         [0]]), array([[ 9],
#         [44],
#         [ 9],
#         ...,
#         [35],
#         [36],
#         [64]])]

# %%
Y_train_2[1][0:5]
# Out:
# array([[ 9],
#        [44],
#        [ 9],
#        [ 6],
#        [21]])

# %% [markdown]
# ### Model

# %%
import time
#start timer after images are uploaded and ready
start = time.time()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten,BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D,Conv2D
from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def Convolution(input_tensor,filters):
    
    x = Conv2D(filters=filters,kernel_size=(3,3),padding = 'same',strides=(1, 1),kernel_regularizer=l2(0.001))(input_tensor)
    x = Dropout(0.1)(x)
    x= Activation('relu')(x)

    return x
def model(input_shape):
  inputs = Input((input_shape))
  
  conv_1= Convolution(inputs,32)
  conv_2 = Convolution(conv_1,32)
  maxp_1 = MaxPooling2D(pool_size = (2,2)) (conv_2)
  drop_1=Dropout(0.25)(maxp_1)
  conv_3= Convolution(drop_1,64)
  conv_4 = Convolution(conv_3,64)
  maxp_2 = MaxPooling2D(pool_size = (2, 2)) (conv_4)
  drop_2=Dropout(0.25)(maxp_2)
  flatten= Flatten() (drop_2)
  dense_1= Dense(64,activation='relu')(flatten)
  drop_2=Dropout(0.2)(dense_1)
  output_1= Dense(1,activation="sigmoid",name='gender_out')(drop_2)
  output_2= Dense(1,activation="relu",name='age_out')(drop_2)
  
  model = Model(inputs=[inputs], outputs=[output_1,output_2])
  model.compile(loss=["binary_crossentropy","mae"], optimizer="Adam",
	metrics=["accuracy"])
  
  return model

# %%
Model=model((48,48,3))

# %%
Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 48, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 48, 48, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 32)   9248        activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 32)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 64)   18496       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           589888      flatten[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# gender_out (Dense)              (None, 1)            65          dropout_6[0][0]
# __________________________________________________________________________________________________
# age_out (Dense)                 (None, 1)            65          dropout_6[0][0]
# ==================================================================================================
# Total params: 655,586
# Trainable params: 655,586
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
fle_s='/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5'
checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
History=Model.fit(X_train,Y_train_2,batch_size=64,validation_data=(X_test,Y_test_2),epochs=30,callbacks=[callback_list])
# Out:
# Epoch 1/30
# 577/577 [==============================] - 45s 20ms/step - loss: 17.3651 - gender_out_loss: 0.9439 - age_out_loss: 16.3000 - gender_out_accuracy: 0.5566 - age_out_accuracy: 0.0248 - val_loss: 17.9243 - val_gender_out_loss: 0.6206 - val_age_out_loss: 17.1941 - val_gender_out_accuracy: 0.6613 - val_age_out_accuracy: 0.0244
#
# Epoch 00001: val_loss improved from inf to 17.92427, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 2/30
# 577/577 [==============================] - 10s 18ms/step - loss: 14.4292 - gender_out_loss: 0.6042 - age_out_loss: 13.7132 - gender_out_accuracy: 0.6749 - age_out_accuracy: 0.0245 - val_loss: 13.9831 - val_gender_out_loss: 0.5243 - val_age_out_loss: 13.3332 - val_gender_out_accuracy: 0.7467 - val_age_out_accuracy: 0.0236
#
# Epoch 00002: val_loss improved from 17.92427 to 13.98314, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 3/30
# 577/577 [==============================] - 11s 18ms/step - loss: 13.0834 - gender_out_loss: 0.5481 - age_out_loss: 12.4032 - gender_out_accuracy: 0.7174 - age_out_accuracy: 0.0244 - val_loss: 14.3099 - val_gender_out_loss: 0.4907 - val_age_out_loss: 13.6686 - val_gender_out_accuracy: 0.7930 - val_age_out_accuracy: 0.0239
#
# Epoch 00003: val_loss did not improve from 13.98314
# Epoch 4/30
# 577/577 [==============================] - 11s 18ms/step - loss: 12.1087 - gender_out_loss: 0.5181 - age_out_loss: 11.4328 - gender_out_accuracy: 0.7440 - age_out_accuracy: 0.0228 - val_loss: 12.3177 - val_gender_out_loss: 0.5014 - val_age_out_loss: 11.6396 - val_gender_out_accuracy: 0.7757 - val_age_out_accuracy: 0.0226
#
# Epoch 00004: val_loss improved from 13.98314 to 12.31773, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 5/30
# 577/577 [==============================] - 11s 18ms/step - loss: 11.3697 - gender_out_loss: 0.5079 - age_out_loss: 10.6795 - gender_out_accuracy: 0.7534 - age_out_accuracy: 0.0216 - val_loss: 12.2340 - val_gender_out_loss: 0.4755 - val_age_out_loss: 11.5586 - val_gender_out_accuracy: 0.7928 - val_age_out_accuracy: 0.0244
#
# Epoch 00005: val_loss improved from 12.31773 to 12.23396, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 6/30
# 577/577 [==============================] - 11s 18ms/step - loss: 10.7394 - gender_out_loss: 0.4982 - age_out_loss: 10.0362 - gender_out_accuracy: 0.7637 - age_out_accuracy: 0.0239 - val_loss: 10.7740 - val_gender_out_loss: 0.4460 - val_age_out_loss: 10.1071 - val_gender_out_accuracy: 0.8075 - val_age_out_accuracy: 0.0244
#
# Epoch 00006: val_loss improved from 12.23396 to 10.77400, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 7/30
# 577/577 [==============================] - 11s 18ms/step - loss: 10.4413 - gender_out_loss: 0.4921 - age_out_loss: 9.7234 - gender_out_accuracy: 0.7653 - age_out_accuracy: 0.0231 - val_loss: 9.0326 - val_gender_out_loss: 0.4432 - val_age_out_loss: 8.3501 - val_gender_out_accuracy: 0.7955 - val_age_out_accuracy: 0.0244
#
# Epoch 00007: val_loss improved from 10.77400 to 9.03258, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 8/30
# 577/577 [==============================] - 11s 18ms/step - loss: 10.1788 - gender_out_loss: 0.4984 - age_out_loss: 9.4376 - gender_out_accuracy: 0.7570 - age_out_accuracy: 0.0246 - val_loss: 10.1105 - val_gender_out_loss: 0.4385 - val_age_out_loss: 9.4191 - val_gender_out_accuracy: 0.8056 - val_age_out_accuracy: 0.0244
#
# Epoch 00008: val_loss did not improve from 9.03258
# Epoch 9/30
# 577/577 [==============================] - 11s 18ms/step - loss: 9.8540 - gender_out_loss: 0.4871 - age_out_loss: 9.1102 - gender_out_accuracy: 0.7640 - age_out_accuracy: 0.0241 - val_loss: 8.8859 - val_gender_out_loss: 0.4468 - val_age_out_loss: 8.1712 - val_gender_out_accuracy: 0.8036 - val_age_out_accuracy: 0.0244
#
# Epoch 00009: val_loss improved from 9.03258 to 8.88594, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 10/30
# 577/577 [==============================] - 11s 18ms/step - loss: 9.6676 - gender_out_loss: 0.4847 - age_out_loss: 8.9115 - gender_out_accuracy: 0.7699 - age_out_accuracy: 0.0252 - val_loss: 9.0121 - val_gender_out_loss: 0.4270 - val_age_out_loss: 8.3035 - val_gender_out_accuracy: 0.8220 - val_age_out_accuracy: 0.0244
#
# Epoch 00010: val_loss did not improve from 8.88594
# Epoch 11/30
# 577/577 [==============================] - 10s 18ms/step - loss: 9.6019 - gender_out_loss: 0.4808 - age_out_loss: 8.8365 - gender_out_accuracy: 0.7752 - age_out_accuracy: 0.0246 - val_loss: 9.9306 - val_gender_out_loss: 0.4240 - val_age_out_loss: 9.2110 - val_gender_out_accuracy: 0.8224 - val_age_out_accuracy: 0.0244
#
# Epoch 00011: val_loss did not improve from 8.88594
# Epoch 12/30
# 577/577 [==============================] - 10s 18ms/step - loss: 9.4263 - gender_out_loss: 0.4615 - age_out_loss: 8.6664 - gender_out_accuracy: 0.7858 - age_out_accuracy: 0.0230 - val_loss: 9.1462 - val_gender_out_loss: 0.4225 - val_age_out_loss: 8.4153 - val_gender_out_accuracy: 0.7987 - val_age_out_accuracy: 0.0244
#
# Epoch 00012: val_loss did not improve from 8.88594
# Epoch 13/30
# 577/577 [==============================] - 10s 18ms/step - loss: 9.3598 - gender_out_loss: 0.4654 - age_out_loss: 8.5835 - gender_out_accuracy: 0.7835 - age_out_accuracy: 0.0242 - val_loss: 8.7100 - val_gender_out_loss: 0.4540 - val_age_out_loss: 7.9359 - val_gender_out_accuracy: 0.8035 - val_age_out_accuracy: 0.0244
#
# Epoch 00013: val_loss improved from 8.88594 to 8.70998, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 14/30
# 577/577 [==============================] - 11s 18ms/step - loss: 9.2977 - gender_out_loss: 0.4664 - age_out_loss: 8.5077 - gender_out_accuracy: 0.7773 - age_out_accuracy: 0.0244 - val_loss: 9.9534 - val_gender_out_loss: 0.4173 - val_age_out_loss: 9.2046 - val_gender_out_accuracy: 0.8229 - val_age_out_accuracy: 0.0244
#
# Epoch 00014: val_loss did not improve from 8.70998
# Epoch 15/30
# 577/577 [==============================] - 11s 18ms/step - loss: 9.2084 - gender_out_loss: 0.4590 - age_out_loss: 8.4151 - gender_out_accuracy: 0.7878 - age_out_accuracy: 0.0238 - val_loss: 8.3826 - val_gender_out_loss: 0.4013 - val_age_out_loss: 7.6398 - val_gender_out_accuracy: 0.8236 - val_age_out_accuracy: 0.0244
#
# Epoch 00015: val_loss improved from 8.70998 to 8.38258, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 16/30
# 577/577 [==============================] - 11s 18ms/step - loss: 9.0970 - gender_out_loss: 0.4517 - age_out_loss: 8.3017 - gender_out_accuracy: 0.7905 - age_out_accuracy: 0.0238 - val_loss: 8.6571 - val_gender_out_loss: 0.3896 - val_age_out_loss: 7.9179 - val_gender_out_accuracy: 0.8355 - val_age_out_accuracy: 0.0244
#
# Epoch 00016: val_loss did not improve from 8.38258
# Epoch 17/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.9969 - gender_out_loss: 0.4427 - age_out_loss: 8.2022 - gender_out_accuracy: 0.7964 - age_out_accuracy: 0.0236 - val_loss: 8.4429 - val_gender_out_loss: 0.3914 - val_age_out_loss: 7.6933 - val_gender_out_accuracy: 0.8342 - val_age_out_accuracy: 0.0244
#
# Epoch 00017: val_loss did not improve from 8.38258
# Epoch 18/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.9555 - gender_out_loss: 0.4379 - age_out_loss: 8.1577 - gender_out_accuracy: 0.7999 - age_out_accuracy: 0.0224 - val_loss: 9.1344 - val_gender_out_loss: 0.3902 - val_age_out_loss: 8.3774 - val_gender_out_accuracy: 0.8401 - val_age_out_accuracy: 0.0244
#
# Epoch 00018: val_loss did not improve from 8.38258
# Epoch 19/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.9026 - gender_out_loss: 0.4349 - age_out_loss: 8.0988 - gender_out_accuracy: 0.8015 - age_out_accuracy: 0.0239 - val_loss: 8.0995 - val_gender_out_loss: 0.3832 - val_age_out_loss: 7.3413 - val_gender_out_accuracy: 0.8268 - val_age_out_accuracy: 0.0244
#
# Epoch 00019: val_loss improved from 8.38258 to 8.09954, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 20/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.8405 - gender_out_loss: 0.4295 - age_out_loss: 8.0334 - gender_out_accuracy: 0.8024 - age_out_accuracy: 0.0245 - val_loss: 7.8544 - val_gender_out_loss: 0.3774 - val_age_out_loss: 7.0934 - val_gender_out_accuracy: 0.8376 - val_age_out_accuracy: 0.0244
#
# Epoch 00020: val_loss improved from 8.09954 to 7.85441, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 21/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.8691 - gender_out_loss: 0.4293 - age_out_loss: 8.0542 - gender_out_accuracy: 0.8051 - age_out_accuracy: 0.0237 - val_loss: 8.5003 - val_gender_out_loss: 0.3876 - val_age_out_loss: 7.7231 - val_gender_out_accuracy: 0.8435 - val_age_out_accuracy: 0.0244
#
# Epoch 00021: val_loss did not improve from 7.85441
# Epoch 22/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.7284 - gender_out_loss: 0.4349 - age_out_loss: 7.9020 - gender_out_accuracy: 0.8040 - age_out_accuracy: 0.0245 - val_loss: 8.4961 - val_gender_out_loss: 0.3901 - val_age_out_loss: 7.7086 - val_gender_out_accuracy: 0.8214 - val_age_out_accuracy: 0.0244
#
# Epoch 00022: val_loss did not improve from 7.85441
# Epoch 23/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.7266 - gender_out_loss: 0.4276 - age_out_loss: 7.8996 - gender_out_accuracy: 0.8058 - age_out_accuracy: 0.0256 - val_loss: 7.9637 - val_gender_out_loss: 0.3733 - val_age_out_loss: 7.1862 - val_gender_out_accuracy: 0.8414 - val_age_out_accuracy: 0.0244
#
# Epoch 00023: val_loss did not improve from 7.85441
# Epoch 24/30
# 577/577 [==============================] - 10s 18ms/step - loss: 8.7221 - gender_out_loss: 0.4257 - age_out_loss: 7.8907 - gender_out_accuracy: 0.8087 - age_out_accuracy: 0.0247 - val_loss: 7.7773 - val_gender_out_loss: 0.3694 - val_age_out_loss: 6.9989 - val_gender_out_accuracy: 0.8431 - val_age_out_accuracy: 0.0244
#
# Epoch 00024: val_loss improved from 7.85441 to 7.77729, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 25/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.7063 - gender_out_loss: 0.4197 - age_out_loss: 7.8763 - gender_out_accuracy: 0.8109 - age_out_accuracy: 0.0251 - val_loss: 9.6716 - val_gender_out_loss: 0.3790 - val_age_out_loss: 8.8778 - val_gender_out_accuracy: 0.8506 - val_age_out_accuracy: 0.0244
#
# Epoch 00025: val_loss did not improve from 7.77729
# Epoch 26/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.6388 - gender_out_loss: 0.4287 - age_out_loss: 7.7944 - gender_out_accuracy: 0.8113 - age_out_accuracy: 0.0251 - val_loss: 8.4760 - val_gender_out_loss: 0.3703 - val_age_out_loss: 7.6856 - val_gender_out_accuracy: 0.8405 - val_age_out_accuracy: 0.0244
#
# Epoch 00026: val_loss did not improve from 7.77729
# Epoch 27/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.6061 - gender_out_loss: 0.4225 - age_out_loss: 7.7622 - gender_out_accuracy: 0.8106 - age_out_accuracy: 0.0254 - val_loss: 8.6570 - val_gender_out_loss: 0.3590 - val_age_out_loss: 7.8731 - val_gender_out_accuracy: 0.8485 - val_age_out_accuracy: 0.0244
#
# Epoch 00027: val_loss did not improve from 7.77729
# Epoch 28/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.5996 - gender_out_loss: 0.4161 - age_out_loss: 7.7566 - gender_out_accuracy: 0.8181 - age_out_accuracy: 0.0266 - val_loss: 8.2247 - val_gender_out_loss: 0.3772 - val_age_out_loss: 7.4173 - val_gender_out_accuracy: 0.8246 - val_age_out_accuracy: 0.0244
#
# Epoch 00028: val_loss did not improve from 7.77729
# Epoch 29/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.4761 - gender_out_loss: 0.4134 - age_out_loss: 7.6319 - gender_out_accuracy: 0.8176 - age_out_accuracy: 0.0231 - val_loss: 7.5536 - val_gender_out_loss: 0.3601 - val_age_out_loss: 6.7602 - val_gender_out_accuracy: 0.8484 - val_age_out_accuracy: 0.0244
#
# Epoch 00029: val_loss improved from 7.77729 to 7.55363, saving model to /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_before_v2.h5
# Epoch 30/30
# 577/577 [==============================] - 11s 18ms/step - loss: 8.5510 - gender_out_loss: 0.4203 - age_out_loss: 7.6961 - gender_out_accuracy: 0.8139 - age_out_accuracy: 0.0240 - val_loss: 9.0366 - val_gender_out_loss: 0.3721 - val_age_out_loss: 8.2261 - val_gender_out_accuracy: 0.8453 - val_age_out_accuracy: 0.0244
#
# Epoch 00030: val_loss did not improve from 7.55363

# %%
fldr="/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_after_v2.h5"
Model.save(fldr)

# %%
#print(saveModel)
tf.saved_model.save(Model, "/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/assets

# %%
end = time.time()
try:
  print(f"Runtime of the full program is {end - begin}")
except: pass

print(f"Runtime of the model training is {end - start}")
# Out:
# Runtime of the model training is 365.4316408634186

# %% [markdown]
# ### Evaluation

# %%
from keras.models import load_model
loaded_model=None
try:
  loaded_model = tf.keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/age_and_gender_3_after.h5")
  loaded_model.summary()
  #loaded_model.evaluate(X_test,Y_test_2)

except: pass
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 48, 32)   416         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 48, 48, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 32)   4128        activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 32)   0           dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 64)   8256        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 24, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 64)   16448       activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 12, 12, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 9216)         0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           589888      flatten[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# gender_out (Dense)              (None, 1)            65          dropout_6[0][0]
# __________________________________________________________________________________________________
# age_out (Dense)                 (None, 1)            65          dropout_6[0][0]
# ==================================================================================================
# Total params: 619,266
# Trainable params: 619,266
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
Model.evaluate(X_test,Y_test_2)
# Out:
# 289/289 [==============================] - 1s 4ms/step - loss: 9.0367 - gender_out_loss: 0.3721 - age_out_loss: 8.2261 - gender_out_accuracy: 0.8453 - age_out_accuracy: 0.0244
# [9.036651611328125,
#  0.3720717430114746,
#  8.22607707977295,
#  0.8452780842781067,
#  0.02439553290605545]

# %%
pred=Model.predict(X_test)

# %%
pred[1]
# Out:
# array([[24.167452 ],
#        [28.336662 ],
#        [ 6.3289967],
#        ...,
#        [15.532295 ],
#        [ 2.9776833],
#        [12.35057  ]], dtype=float32)

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For Gender

# %%
plt.plot(History.history['gender_out_accuracy'])
plt.plot(History.history['val_gender_out_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For age

# %%
fig, ax = plt.subplots()
ax.scatter(Y_test_2[1], pred[1])
ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %% [markdown]
# #### For Gender

# %%
i=0
Pred_l=[]
while(i<len(pred[0])):

  Pred_l.append(int(np.round(pred[0][i])))
  i+=1

# %%
from sklearn.metrics import confusion_matrix 

from sklearn.metrics import classification_report

# %%
report=classification_report(Y_test_2[0], Pred_l)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      5400
#            1       0.89      0.71      0.79      3823
#
#     accuracy                           0.85      9223
#    macro avg       0.86      0.83      0.83      9223
# weighted avg       0.85      0.85      0.84      9223

# %%
results = confusion_matrix(Y_test_2[0], Pred_l)

# %%
#test
import cv2
import numpy as np
uploaded_image = cv2.imread('/content/drive/MyDrive/male_face.jpg', cv2.IMREAD_UNCHANGED)

# %%
from skimage.transform import resize  
from google.colab.patches import cv2_imshow
img_resized = cv2.resize(uploaded_image,(48,48))
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F17692797D0>

# %%
#online
from urllib import request
from google.colab.patches import cv2_imshow
url = 'data:image/png;base64,...'
res = request.urlopen(url)
img = np.asarray(bytearray(res.read()), dtype='uint8')
imm = cv2.imdecode(img, cv2.COLOR_RGB2BGR)
cv2_imshow(imm)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F175E076B50>

# %%
#!pip install mtcnn
# !pip install mtcnn
import mtcnn
from mtcnn.mtcnn import MTCNN
import PIL
from PIL import Image

img = np.asarray(imm, dtype='uint8')
detector = MTCNN()
# detekcija face(pozicija ociju,usta...)
detections = detector.detect_faces(img)
print(detections)
x1, y1, width, height = detections[0]['box']
dw = round(width * 0)
dh = round(height * 0)
x2, y2 = x1 + width + dw, y1 + height + dh
face = img[y1:y2, x1:x2]

# resize
face = PIL.Image.fromarray(face)
face = face.resize((48, 48))
face = np.asarray(face)
cv2_imshow(face)
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 14.8MB/s
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras>=2.0.0->mtcnn) (1.15.0)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0
# WARNING:tensorflow:5 out of the last 293 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f173c0ef710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 294 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f173c0545f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [{'box': [3, 0, 38, 45], 'confidence': 0.9198365807533264, 'keypoints': {'left_eye': (15, 13), 'right_eye': (33, 13), 'nose': (24, 23), 'mouth_left': (17, 33), 'mouth_right': (31, 33)}}]
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F1758070990>

# %%
#testiranje na vlastitim slikama

from google.colab.patches import cv2_imshow
import cv2
def test_image(imma):

  #pretvorba nazad u rgb format
  #img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/male.jpg')
  image = cv2.cvtColor(imma, cv2.COLOR_BGR2RGB)
  
  cv2_imshow(image)
  image_test=image/255

  #podaci iz slike i modela
  pred_1=Model.predict(np.array([image_test]))
  #print(pred_1)
  gender_f=['Male','Female']
  age=int(np.round(pred_1[1][0]))
  gender=int(np.round(pred_1[0][0]))

  print("Predicted Age: "+ str(age))
  print("Predicted Gender: "+ gender_f[gender])

# %%
test_image(face)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7F17B02C4890>
# Predicted Age: 56
# Predicted Gender: Male

# %%
#testiranje na slikama iz testnog uzorka
rom google.colab.patches import cv2_imshow
import cv2
def test_image(ind,images_f,images_f_2,Model):

  #pretvorba nazad u rgb format
  image = cv2.cvtColor(images_f[ind], cv2.COLOR_BGR2RGB)
  cv2_imshow(image)
  image_test=images_f_2[ind]

  #podaci iz slike i modela
  pred_1=Model.predict(np.array([image_test]))
  #print(pred_1)
  gender_f=['Male','Female']
  age=int(np.round(pred_1[1][0]))
  gender=int(np.round(pred_1[0][0]))

  print()
  print("Predicted Age: "+ str(age))
  print("Real Age: "+ str(ages_f[ind]))
  print("Predicted Gender: "+ gender_f[gender])
  print("Real Gender: "+ gender_f[genders_f[ind]])
# Out:
#   File "<ipython-input-48-485a0dfb8cb5>", line 2
#     rom google.colab.patches import cv2_imshow
#              ^
# SyntaxError: invalid syntax

# %%
test_image(700,images_f,images_f_2,Model)

# %%
test_image(137,images_f,images_f_2,Model)

# %%
test_image(502,images_f,images_f_2,Model)

# %%
test_image(24,images_f,images_f_2,Model)
