# %% [markdown]
# #### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import time

#starting time -> da izmjerimo koliko programu treba da se sav kod izvrši
begin = time.time()

# %% [markdown]
# #### Data Preprocessing

# %%
fldr="/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFace"

# %%
import os
files=os.listdir(fldr)

# %%
#prolazimo kroz svaku sliku i iz naziva uzimamo podatke o godinama i spolu(prvo broj u nazivu označava godine, a drugi spol)
#0- muško, 1-žensko
import cv2
ages=[]
genders=[]
images=[]

for fle in files:
  #iz slike uzimamo podatke i spremamo u polje
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)

  #učitavanje slike iz putanje kao polje piksela, promjena formata boje i rezising te spremanje u polje
  total=fldr+'/'+fle
  #print(total)
  image=cv2.imread(total)

  #iz dokumentacije: When the image file is read with the OpenCV function imread(), the order of colors is BGR
    #Therefore, if you want to use both the Pillow function and the OpenCV function, you need to convert BGR and RGB.
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image= cv2.resize(image,(48,48))
  images.append(image)

print("finished")
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FBF946596D8>
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FBF94659668>
# finished

# %%
# start timer after images are uploaded and ready
#start = time.time()

# %%
''' visak 
for fle in files:
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)
'''

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(images[24])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA826F18C50>

# %%
print(ages[24])
print(genders[24])
# Out:
# 80
# 1

# %%
cv2_imshow(images[53])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA81D2BC780>

# %%
print(ages[53])
print(genders[53])
# Out:
# 80
# 1

# %%
import numpy as np
images_f=np.array(images)
genders_f=np.array(genders)
ages_f=np.array(ages)

# %%
np.save(fldr+'image.npy',images_f)
np.save(fldr+'gender.npy',genders_f)
np.save(fldr+'age.npy',ages_f)

# %%
#loadanje ako smo već jednom obradili
import numpy as np
genders_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFacegender2.npy')
images_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceimage2.npy')
ages_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceage2.npy')

# %% [markdown]
# Male = 0
# Female= 1

# %%
values, counts = np.unique(genders_f, return_counts=True)
print(counts)
# Out:
# [27153 18961]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male', 'Female']
values=[counts[0],counts[1]]
ax.bar(gender,values)
plt.show()

# %%
#vidimo da ima npr 1123 osoba s 1 godinom i 4 osobe za 116 godina
values, counts = np.unique(ages_f, return_counts=True)
print(counts)
# Out:
# [1123  720  459  452  367  351  324  454  363  289  229  312  289  312
#   334  405  334  478  306  518  558  698  755 1224 1129 2672 1261 1454
#  1281 1208  881 1314  780  997 1564 1187  951  815  738 1020  674  776
#   627  462  862  525  526  433  482  621  366  448  473  599  522  546
#   337  411  296  513  359  249  279  170  365  215  248  216  204  241
#   127  158  163  132  220  158  128  191  109  237   22   40   18   24
#   155   35   10   34   33   82    2   13    5    9   17    9   11    2
#     1    5    5    1    3    4]

# %%
#val=values.tolist()
cnt=counts.tolist()

# %%
#u bazi podataka najviše dvadesetogodišnjaka
plt.plot(counts)
plt.xlabel('ages')
plt.ylabel('distribution')
plt.show()

# %%
#pripremanje kategorija za varijablu Y
labels=[]

i=0
while i<len(ages_f):
  label=[]
  label.append([ages_f[i]])
  label.append([genders_f[i]])
  labels.append(label)
  i+=1

# %%
#normalizacija podataka
images_f_2=images_f/255

# %%
labels_f=np.array(labels)

# %%
images_f_2.shape
# Out:
# (46114, 48, 48, 3)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(images_f_2, labels_f,test_size=0.25)

# %%
#prvi element označava godine, drugi spol
Y_train[0:5]
# Out:
# array([[[35],
#         [ 1]],
#
#        [[26],
#         [ 1]],
#
#        [[ 1],
#         [ 0]],
#
#        [[32],
#         [ 1]],
#
#        [[46],
#         [ 0]]])

# %%
#pretvaranje iz oblika [[[godina], [spol]],...] u oblik [[godina],[godina],...][[spol], [spol],...]] dakle iz toga da u svaki array sadrži godinu i spol u oblik da jedan array sadrži godinu a drugi spol
Y_train_2=[Y_train[:,1],Y_train[:,0]]
Y_test_2=[Y_test[:,1],Y_test[:,0]]

# %%
Y_train_2
# Out:
# [array([[1],
#         [1],
#         [0],
#         ...,
#         [0],
#         [0],
#         [1]]), array([[35],
#         [26],
#         [ 1],
#         ...,
#         [27],
#         [34],
#         [27]])]

# %%
Y_train_2[1][0:5]
# Out:
# array([[35],
#        [26],
#        [ 1],
#        [32],
#        [46]])

# %% [markdown]
# ### Model

# %%
import time
#start timer after images are uploaded and ready
start = time.time()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten,BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D,Conv2D
from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

def Convolution(input_tensor,filters):
    
    x = Conv2D(filters=filters,kernel_size=(3, 3),padding = 'same',strides=(1, 1),kernel_regularizer=l2(0.001))(input_tensor)
    x = Dropout(0.1)(x)
    x= Activation('relu')(x)

    return x
def model(input_shape):
  inputs = Input((input_shape))
  
  conv_1= Convolution(inputs,32)
  maxp_1 = MaxPooling2D(pool_size = (2,2)) (conv_1)
  drop_1=Dropout(0.2)(maxp_1)

  conv_2 = Convolution(drop_1,64)
  maxp_2 = MaxPooling2D(pool_size = (2,2)) (conv_2)
  conv_3= Convolution(maxp_2,128)
  conv_4 = Convolution(conv_3,256)
  
  flatten= Flatten() (conv_4)
  dense_1= Dense(256,activation='relu')(flatten)
  output_1= Dense(1,activation="sigmoid",name='gender_out')(dense_1)
  output_2= Dense(1,activation="relu",name='age_out')(dense_1)
  
  model = Model(inputs=[inputs], outputs=[output_1,output_2])
  model.compile(loss=["binary_crossentropy","mae"], optimizer="Adam",
	metrics=["accuracy"])
  
  return model

# %%
Model=model((48,48,3))

# %%
Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 48, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 48, 48, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 24, 24, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 24, 24, 64)   18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 64)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 24, 24, 64)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 12, 12, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 12, 12, 128)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 12, 12, 128)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 256)  295168      activation_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 12, 12, 256)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 36864)        0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          9437440     flatten[0][0]
# __________________________________________________________________________________________________
# gender_out (Dense)              (None, 1)            257         dense[0][0]
# __________________________________________________________________________________________________
# age_out (Dense)                 (None, 1)            257         dense[0][0]
# ==================================================================================================
# Total params: 9,826,370
# Trainable params: 9,826,370
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
fle_s='Age_and_gender55.h5'
checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
History=Model.fit(X_train,Y_train_2,batch_size=64,validation_data=(X_test,Y_test_2),epochs=30,callbacks=[callback_list])
# Out:
# Epoch 1/30
# 541/541 [==============================] - 44s 19ms/step - loss: 16.7338 - gender_out_loss: 0.9250 - age_out_loss: 15.6090 - gender_out_accuracy: 0.5878 - age_out_accuracy: 0.0249 - val_loss: 12.2190 - val_gender_out_loss: 0.5123 - val_age_out_loss: 11.5370 - val_gender_out_accuracy: 0.7560 - val_age_out_accuracy: 0.0242
#
# Epoch 00001: val_loss improved from inf to 12.21900, saving model to Age_and_gender55.h5
# Epoch 2/30
# 541/541 [==============================] - 9s 17ms/step - loss: 11.9786 - gender_out_loss: 0.5230 - age_out_loss: 11.2825 - gender_out_accuracy: 0.7465 - age_out_accuracy: 0.0234 - val_loss: 10.8580 - val_gender_out_loss: 0.4708 - val_age_out_loss: 10.1943 - val_gender_out_accuracy: 0.7790 - val_age_out_accuracy: 0.0242
#
# Epoch 00002: val_loss improved from 12.21900 to 10.85801, saving model to Age_and_gender55.h5
# Epoch 3/30
# 541/541 [==============================] - 9s 17ms/step - loss: 10.8038 - gender_out_loss: 0.4777 - age_out_loss: 10.1261 - gender_out_accuracy: 0.7716 - age_out_accuracy: 0.0251 - val_loss: 9.7506 - val_gender_out_loss: 0.4353 - val_age_out_loss: 9.0912 - val_gender_out_accuracy: 0.7963 - val_age_out_accuracy: 0.0242
#
# Epoch 00003: val_loss improved from 10.85801 to 9.75058, saving model to Age_and_gender55.h5
# Epoch 4/30
# 541/541 [==============================] - 9s 17ms/step - loss: 9.9291 - gender_out_loss: 0.4395 - age_out_loss: 9.2592 - gender_out_accuracy: 0.7995 - age_out_accuracy: 0.0237 - val_loss: 10.2312 - val_gender_out_loss: 0.4643 - val_age_out_loss: 9.5139 - val_gender_out_accuracy: 0.7756 - val_age_out_accuracy: 0.0242
#
# Epoch 00004: val_loss did not improve from 9.75058
# Epoch 5/30
# 541/541 [==============================] - 9s 17ms/step - loss: 9.5114 - gender_out_loss: 0.4141 - age_out_loss: 8.8382 - gender_out_accuracy: 0.8101 - age_out_accuracy: 0.0248 - val_loss: 9.0942 - val_gender_out_loss: 0.3909 - val_age_out_loss: 8.4243 - val_gender_out_accuracy: 0.8192 - val_age_out_accuracy: 0.0242
#
# Epoch 00005: val_loss improved from 9.75058 to 9.09417, saving model to Age_and_gender55.h5
# Epoch 6/30
# 541/541 [==============================] - 9s 17ms/step - loss: 9.0486 - gender_out_loss: 0.3965 - age_out_loss: 8.3655 - gender_out_accuracy: 0.8189 - age_out_accuracy: 0.0241 - val_loss: 9.1471 - val_gender_out_loss: 0.3916 - val_age_out_loss: 8.4469 - val_gender_out_accuracy: 0.8157 - val_age_out_accuracy: 0.0242
#
# Epoch 00006: val_loss did not improve from 9.09417
# Epoch 7/30
# 541/541 [==============================] - 9s 17ms/step - loss: 8.8837 - gender_out_loss: 0.3827 - age_out_loss: 8.1841 - gender_out_accuracy: 0.8290 - age_out_accuracy: 0.0240 - val_loss: 8.5494 - val_gender_out_loss: 0.3459 - val_age_out_loss: 7.8661 - val_gender_out_accuracy: 0.8450 - val_age_out_accuracy: 0.0242
#
# Epoch 00007: val_loss improved from 9.09417 to 8.54941, saving model to Age_and_gender55.h5
# Epoch 8/30
# 541/541 [==============================] - 9s 17ms/step - loss: 8.6029 - gender_out_loss: 0.3639 - age_out_loss: 7.8927 - gender_out_accuracy: 0.8376 - age_out_accuracy: 0.0248 - val_loss: 8.5111 - val_gender_out_loss: 0.3417 - val_age_out_loss: 7.7986 - val_gender_out_accuracy: 0.8513 - val_age_out_accuracy: 0.0242
#
# Epoch 00008: val_loss improved from 8.54941 to 8.51107, saving model to Age_and_gender55.h5
# Epoch 9/30
# 541/541 [==============================] - 9s 17ms/step - loss: 8.3047 - gender_out_loss: 0.3477 - age_out_loss: 7.5802 - gender_out_accuracy: 0.8456 - age_out_accuracy: 0.0247 - val_loss: 8.7297 - val_gender_out_loss: 0.3415 - val_age_out_loss: 7.9927 - val_gender_out_accuracy: 0.8472 - val_age_out_accuracy: 0.0242
#
# Epoch 00009: val_loss did not improve from 8.51107
# Epoch 10/30
# 541/541 [==============================] - 9s 17ms/step - loss: 8.1651 - gender_out_loss: 0.3477 - age_out_loss: 7.4152 - gender_out_accuracy: 0.8450 - age_out_accuracy: 0.0249 - val_loss: 8.3426 - val_gender_out_loss: 0.3339 - val_age_out_loss: 7.5864 - val_gender_out_accuracy: 0.8536 - val_age_out_accuracy: 0.0242
#
# Epoch 00010: val_loss improved from 8.51107 to 8.34257, saving model to Age_and_gender55.h5
# Epoch 11/30
# 541/541 [==============================] - 9s 17ms/step - loss: 8.0196 - gender_out_loss: 0.3303 - age_out_loss: 7.2599 - gender_out_accuracy: 0.8541 - age_out_accuracy: 0.0240 - val_loss: 7.9883 - val_gender_out_loss: 0.3213 - val_age_out_loss: 7.2183 - val_gender_out_accuracy: 0.8632 - val_age_out_accuracy: 0.0242
#
# Epoch 00011: val_loss improved from 8.34257 to 7.98827, saving model to Age_and_gender55.h5
# Epoch 12/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.8647 - gender_out_loss: 0.3168 - age_out_loss: 7.0927 - gender_out_accuracy: 0.8582 - age_out_accuracy: 0.0253 - val_loss: 8.0763 - val_gender_out_loss: 0.3133 - val_age_out_loss: 7.2905 - val_gender_out_accuracy: 0.8663 - val_age_out_accuracy: 0.0242
#
# Epoch 00012: val_loss did not improve from 7.98827
# Epoch 13/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.6672 - gender_out_loss: 0.3092 - age_out_loss: 6.8788 - gender_out_accuracy: 0.8654 - age_out_accuracy: 0.0241 - val_loss: 7.9455 - val_gender_out_loss: 0.3221 - val_age_out_loss: 7.1257 - val_gender_out_accuracy: 0.8629 - val_age_out_accuracy: 0.0242
#
# Epoch 00013: val_loss improved from 7.98827 to 7.94546, saving model to Age_and_gender55.h5
# Epoch 14/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.5554 - gender_out_loss: 0.3107 - age_out_loss: 6.7407 - gender_out_accuracy: 0.8667 - age_out_accuracy: 0.0238 - val_loss: 7.8114 - val_gender_out_loss: 0.2999 - val_age_out_loss: 6.9878 - val_gender_out_accuracy: 0.8731 - val_age_out_accuracy: 0.0242
#
# Epoch 00014: val_loss improved from 7.94546 to 7.81141, saving model to Age_and_gender55.h5
# Epoch 15/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.5139 - gender_out_loss: 0.2953 - age_out_loss: 6.6874 - gender_out_accuracy: 0.8732 - age_out_accuracy: 0.0248 - val_loss: 7.7768 - val_gender_out_loss: 0.2982 - val_age_out_loss: 6.9309 - val_gender_out_accuracy: 0.8767 - val_age_out_accuracy: 0.0242
#
# Epoch 00015: val_loss improved from 7.81141 to 7.77675, saving model to Age_and_gender55.h5
# Epoch 16/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.3920 - gender_out_loss: 0.2869 - age_out_loss: 6.5509 - gender_out_accuracy: 0.8785 - age_out_accuracy: 0.0228 - val_loss: 7.9785 - val_gender_out_loss: 0.3498 - val_age_out_loss: 7.0579 - val_gender_out_accuracy: 0.8386 - val_age_out_accuracy: 0.0242
#
# Epoch 00016: val_loss did not improve from 7.77675
# Epoch 17/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.3077 - gender_out_loss: 0.2926 - age_out_loss: 6.4392 - gender_out_accuracy: 0.8773 - age_out_accuracy: 0.0243 - val_loss: 8.1211 - val_gender_out_loss: 0.2995 - val_age_out_loss: 7.2307 - val_gender_out_accuracy: 0.8772 - val_age_out_accuracy: 0.0242
#
# Epoch 00017: val_loss did not improve from 7.77675
# Epoch 18/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.1550 - gender_out_loss: 0.2809 - age_out_loss: 6.2788 - gender_out_accuracy: 0.8787 - age_out_accuracy: 0.0257 - val_loss: 7.6873 - val_gender_out_loss: 0.3126 - val_age_out_loss: 6.7649 - val_gender_out_accuracy: 0.8661 - val_age_out_accuracy: 0.0242
#
# Epoch 00018: val_loss improved from 7.77675 to 7.68727, saving model to Age_and_gender55.h5
# Epoch 19/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.0904 - gender_out_loss: 0.2730 - age_out_loss: 6.2019 - gender_out_accuracy: 0.8815 - age_out_accuracy: 0.0246 - val_loss: 7.6755 - val_gender_out_loss: 0.3094 - val_age_out_loss: 6.7355 - val_gender_out_accuracy: 0.8672 - val_age_out_accuracy: 0.0242
#
# Epoch 00019: val_loss improved from 7.68727 to 7.67549, saving model to Age_and_gender55.h5
# Epoch 20/30
# 541/541 [==============================] - 9s 17ms/step - loss: 7.0298 - gender_out_loss: 0.2588 - age_out_loss: 6.1361 - gender_out_accuracy: 0.8908 - age_out_accuracy: 0.0245 - val_loss: 7.5795 - val_gender_out_loss: 0.2873 - val_age_out_loss: 6.6418 - val_gender_out_accuracy: 0.8779 - val_age_out_accuracy: 0.0242
#
# Epoch 00020: val_loss improved from 7.67549 to 7.57947, saving model to Age_and_gender55.h5
# Epoch 21/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.9330 - gender_out_loss: 0.2543 - age_out_loss: 6.0236 - gender_out_accuracy: 0.8925 - age_out_accuracy: 0.0231 - val_loss: 7.5655 - val_gender_out_loss: 0.2924 - val_age_out_loss: 6.6051 - val_gender_out_accuracy: 0.8774 - val_age_out_accuracy: 0.0242
#
# Epoch 00021: val_loss improved from 7.57947 to 7.56548, saving model to Age_and_gender55.h5
# Epoch 22/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.8419 - gender_out_loss: 0.2524 - age_out_loss: 5.9175 - gender_out_accuracy: 0.8918 - age_out_accuracy: 0.0251 - val_loss: 7.4490 - val_gender_out_loss: 0.2825 - val_age_out_loss: 6.4838 - val_gender_out_accuracy: 0.8837 - val_age_out_accuracy: 0.0242
#
# Epoch 00022: val_loss improved from 7.56548 to 7.44900, saving model to Age_and_gender55.h5
# Epoch 23/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.6985 - gender_out_loss: 0.2440 - age_out_loss: 5.7682 - gender_out_accuracy: 0.8974 - age_out_accuracy: 0.0249 - val_loss: 7.8589 - val_gender_out_loss: 0.2808 - val_age_out_loss: 6.8794 - val_gender_out_accuracy: 0.8826 - val_age_out_accuracy: 0.0242
#
# Epoch 00023: val_loss did not improve from 7.44900
# Epoch 24/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.7242 - gender_out_loss: 0.2418 - age_out_loss: 5.7800 - gender_out_accuracy: 0.8968 - age_out_accuracy: 0.0235 - val_loss: 7.5868 - val_gender_out_loss: 0.2802 - val_age_out_loss: 6.5950 - val_gender_out_accuracy: 0.8852 - val_age_out_accuracy: 0.0242
#
# Epoch 00024: val_loss did not improve from 7.44900
# Epoch 25/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.6953 - gender_out_loss: 0.2327 - age_out_loss: 5.7464 - gender_out_accuracy: 0.9033 - age_out_accuracy: 0.0243 - val_loss: 7.3809 - val_gender_out_loss: 0.2768 - val_age_out_loss: 6.3764 - val_gender_out_accuracy: 0.8880 - val_age_out_accuracy: 0.0242
#
# Epoch 00025: val_loss improved from 7.44900 to 7.38088, saving model to Age_and_gender55.h5
# Epoch 26/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.6247 - gender_out_loss: 0.2233 - age_out_loss: 5.6706 - gender_out_accuracy: 0.9075 - age_out_accuracy: 0.0238 - val_loss: 7.5317 - val_gender_out_loss: 0.3019 - val_age_out_loss: 6.4897 - val_gender_out_accuracy: 0.8754 - val_age_out_accuracy: 0.0242
#
# Epoch 00026: val_loss did not improve from 7.38088
# Epoch 27/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.6145 - gender_out_loss: 0.2180 - age_out_loss: 5.6531 - gender_out_accuracy: 0.9086 - age_out_accuracy: 0.0259 - val_loss: 7.5823 - val_gender_out_loss: 0.2865 - val_age_out_loss: 6.5446 - val_gender_out_accuracy: 0.8825 - val_age_out_accuracy: 0.0242
#
# Epoch 00027: val_loss did not improve from 7.38088
# Epoch 28/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.5822 - gender_out_loss: 0.2168 - age_out_loss: 5.6109 - gender_out_accuracy: 0.9096 - age_out_accuracy: 0.0229 - val_loss: 7.4324 - val_gender_out_loss: 0.2878 - val_age_out_loss: 6.3833 - val_gender_out_accuracy: 0.8820 - val_age_out_accuracy: 0.0242
#
# Epoch 00028: val_loss did not improve from 7.38088
# Epoch 29/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.4454 - gender_out_loss: 0.2044 - age_out_loss: 5.4760 - gender_out_accuracy: 0.9148 - age_out_accuracy: 0.0245 - val_loss: 7.4847 - val_gender_out_loss: 0.3035 - val_age_out_loss: 6.4079 - val_gender_out_accuracy: 0.8793 - val_age_out_accuracy: 0.0242
#
# Epoch 00029: val_loss did not improve from 7.38088
# Epoch 30/30
# 541/541 [==============================] - 9s 17ms/step - loss: 6.3349 - gender_out_loss: 0.2085 - age_out_loss: 5.3507 - gender_out_accuracy: 0.9144 - age_out_accuracy: 0.0245 - val_loss: 7.8917 - val_gender_out_loss: 0.2851 - val_age_out_loss: 6.8253 - val_gender_out_accuracy: 0.8834 - val_age_out_accuracy: 0.0242
#
# Epoch 00030: val_loss did not improve from 7.38088

# %%
#ne radi
Model.save('age_and_gender_5.h5')

# %%
#drugi nacin za spremanje
saveModel='age_and_gender_55.h5'
checkpointer = ModelCheckpoint(saveModel, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
end = time.time()
try:
  print(f"Runtime of the full program is {end - begin}")
except: pass

print(f"Runtime of the model training is {end - start}")
# Out:
# Runtime of the model training is 318.2528133392334

# %% [markdown]
# ### Evaluation

# %%
Model.evaluate(X_test,Y_test_2)
# Out:
# 361/361 [==============================] - 1s 4ms/step - loss: 7.8917 - gender_out_loss: 0.2851 - age_out_loss: 6.8253 - gender_out_accuracy: 0.8834 - age_out_accuracy: 0.0242
# [7.89166259765625,
#  0.2850607931613922,
#  6.825334548950195,
#  0.8834244012832642,
#  0.024199843406677246]

# %%
pred=Model.predict(X_test)

# %%
pred[1]
# Out:
# array([[34.21885 ],
#        [30.486906],
#        [67.47847 ],
#        ...,
#        [40.733833],
#        [44.63317 ],
#        [35.006462]], dtype=float32)

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For Gender

# %%
plt.plot(History.history['gender_out_accuracy'])
plt.plot(History.history['val_gender_out_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For age

# %%
fig, ax = plt.subplots()
ax.scatter(Y_test_2[1], pred[1])
ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %% [markdown]
# #### For Gender

# %%
i=0
Pred_l=[]
while(i<len(pred[0])):

  Pred_l.append(int(np.round(pred[0][i])))
  i+=1

# %%
from sklearn.metrics import confusion_matrix 

from sklearn.metrics import classification_report

# %%
report=classification_report(Y_test_2[0], Pred_l)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90      6769
#            1       0.83      0.90      0.86      4760
#
#     accuracy                           0.88     11529
#    macro avg       0.88      0.89      0.88     11529
# weighted avg       0.89      0.88      0.88     11529

# %%
results = confusion_matrix(Y_test_2[0], Pred_l)

# %%
from google.colab.patches import cv2_imshow
import cv2
def test_image(ind,images_f,images_f_2,Model):

  #pretvorba nazad u rgb format
  image = cv2.cvtColor(images_f[ind], cv2.COLOR_BGR2RGB)
  cv2_imshow(image)
  image_test=images_f_2[ind]

  #podaci iz slike i modela
  pred_1=Model.predict(np.array([image_test]))
  #print(pred_1)
  gender_f=['Male','Female']
  age=int(np.round(pred_1[1][0]))
  gender=int(np.round(pred_1[0][0]))

  print("Predicted Age: "+ str(age))
  print("Real Age: "+ str(ages_f[ind]))
  print("Predicted Gender: "+ gender_f[gender])
  print("Real Gender: "+ gender_f[genders_f[ind]])

# %%
from google.colab.patches import cv2_imshow
test_image(57,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA1B7534E50>
# Predicted Age: 66
# Real Age: 80
# Predicted Gender: Female
# Real Gender: Female

# %%
test_image(137,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA1960E6D50>
# Predicted Age: 72
# Real Age: 83
# Predicted Gender: Female
# Real Gender: Female

# %%
test_image(502,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA1960D0A50>
# Predicted Age: 8
# Real Age: 8
# Predicted Gender: Female
# Real Gender: Female

# %%
test_image(24,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA196098310>
# Predicted Age: 71
# Real Age: 80
# Predicted Gender: Female
# Real Gender: Female
