# %% [markdown]
# #### Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time

#starting time -> da izmjerimo koliko programu treba da se sav kod izvrši
begin = time.time()

# %% [markdown]
# #### Data Preprocessing

# %%
fldr="/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFace"

# %%
import os
files=os.listdir(fldr)

# %%
#prolazimo kroz svaku sliku i iz naziva uzimamo podatke o godinama i spolu(prvo broj u nazivu označava godine, a drugi spol)
#0- muško, 1-žensko
import cv2
ages=[]
genders=[]
images=[]

for fle in files:
  #iz slike uzimamo podatke i spremamo u polje
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)

  #učitavanje slike iz putanje kao polje piksela, promjena formata boje i rezising te spremanje u polje
  total=fldr+'/'+fle
  #print(total)
  image=cv2.imread(total)

  #iz dokumentacije: When the image file is read with the OpenCV function imread(), the order of colors is BGR
    #Therefore, if you want to use both the Pillow function and the OpenCV function, you need to convert BGR and RGB.
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image= cv2.resize(image,(48,48))
  images.append(image)

print("finished")
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FBF946596D8>
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FBF94659668>
# finished

# %%
# start timer after images are uploaded and ready
#start = time.time()

# %%
''' visak 
for fle in files:
  age=int(fle.split('_')[0])
  gender=int(fle.split('_')[1])
  ages.append(age)
  genders.append(gender)
'''

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(images[24])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA826F18C50>

# %%
print(ages[24])
print(genders[24])
# Out:
# 80
# 1

# %%
cv2_imshow(images[53])
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FA81D2BC780>

# %%
print(ages[53])
print(genders[53])
# Out:
# 80
# 1

# %%
import numpy as np
images_f=np.array(images)
genders_f=np.array(genders)
ages_f=np.array(ages)

# %%
np.save(fldr+'image.npy',images_f)
np.save(fldr+'gender.npy',genders_f)
np.save(fldr+'age.npy',ages_f)

# %%
#loadanje ako smo već jednom obradili
import numpy as np
genders_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFacegender.npy')
images_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceimage.npy')
ages_f = np.load('/content/drive/MyDrive/Colab Notebooks/Face_data_based_deeplearning/UTKFaceage.npy')

# %% [markdown]
# Male = 0
# Female= 1

# %%
values, counts = np.unique(genders_f, return_counts=True)
print(counts)
# Out:
# [12391 11317]

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
gender = ['Male', 'Female']
values=[counts[0],counts[1]]
ax.bar(gender,values)
plt.show()

# %%
#vidimo da ima npr 1123 osoba s 1 godinom i 4 osobe za 116 godina
values, counts = np.unique(ages_f, return_counts=True)
print(counts)
# Out:
# [1123  482  289  273  196  131  139  263  166  156   65  130   81  157
#   177  247  158  262   98  284  346  395  426  859  734 2197  615  918
#   570  724  350  664  143  409  880  483  293  325  266  526  132  266
#   157  100  440  153  170  153  148  381  138  232  241  353  268  236
#    97  271   82  293  161  125  103   50  259   77   94  100   56  147
#    33   98   63   32  148   58   28   69   23  133   22   40   18   24
#   155   35   10   34   33   82    2   13    5    9   17    9   11    2
#     1    5    5    1    3    4]

# %%
#val=values.tolist()
cnt=counts.tolist()

# %%
#u bazi podataka najviše dvadesetogodišnjaka
plt.plot(counts)
plt.xlabel('ages')
plt.ylabel('distribution')
plt.show()

# %%
#pripremanje kategorija za varijablu Y
labels=[]

i=0
while i<len(ages_f):
  label=[]
  label.append([ages_f[i]])
  label.append([genders_f[i]])
  labels.append(label)
  i+=1

# %%
#normalizacija podataka
images_f_2=images_f/255

# %%
labels_f=np.array(labels)

# %%
images_f_2.shape
# Out:
# (23708, 48, 48, 3)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(images_f_2, labels_f,test_size=0.25)

# %%
#prvi element označava godine, drugi spol
Y_train[0:5]
# Out:
# array([[[26],
#         [ 1]],
#
#        [[76],
#         [ 1]],
#
#        [[88],
#         [ 1]],
#
#        [[35],
#         [ 0]],
#
#        [[65],
#         [ 1]]])

# %%
#pretvaranje iz oblika [[[godina], [spol]],...] u oblik [[godina],[godina],...][[spol], [spol],...]] dakle iz toga da u svaki array sadrži godinu i spol u oblik da jedan array sadrži godinu a drugi spol
Y_train_2=[Y_train[:,1],Y_train[:,0]]
Y_test_2=[Y_test[:,1],Y_test[:,0]]

# %%
Y_train_2
# Out:
# [array([[1],
#         [1],
#         [1],
#         ...,
#         [1],
#         [1],
#         [0]]), array([[26],
#         [76],
#         [88],
#         ...,
#         [24],
#         [ 6],
#         [37]])]

# %%
Y_train_2[1][0:5]
# Out:
# array([[26],
#        [76],
#        [88],
#        [35],
#        [65]])

# %% [markdown]
# ### Model

# %%
import time
#start timer after images are uploaded and ready
start = time.time()

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten,BatchNormalization
from tensorflow.keras.layers import Dense, MaxPooling2D,Conv2D
from tensorflow.keras.layers import Input,Activation,Add
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

#https://towardsdatascience.com/cnn-architectures-a-deep-dive-a99441d18049
def Convolution(input_tensor,filters):
    
    x = Conv2D(filters=filters,kernel_size=(3, 3),padding = 'same',strides=(1, 1),kernel_regularizer=l2(0.001))(input_tensor)
    x = Dropout(0.1)(x)
    x= Activation('relu')(x)

    return x
def model(input_shape):
  inputs = Input((input_shape))
  
  conv_1= Convolution(inputs,32)
  drop_1=Dropout(0.4)(conv_1)
  conv_2= Convolution(drop_1,32)
  drop_2=Dropout(0.4)(conv_2)
  maxp_1 = MaxPooling2D(pool_size = (2,2)) (drop_2)

  conv_3= Convolution(maxp_1,64)
  drop_3=Dropout(0.4)(conv_3)
  conv_4= Convolution(drop_3,64)
  drop_4=Dropout(0.4)(conv_4)
  maxp_2 = MaxPooling2D(pool_size = (2,2)) (drop_4)

  conv_5= Convolution(maxp_2,128)
  drop_5=Dropout(0.4)(conv_5)
  conv_6= Convolution(drop_5,128)
  drop_6=Dropout(0.4)(conv_6)
  maxp_3 = MaxPooling2D(pool_size = (2,2)) (drop_6)

  flatten= Flatten() (maxp_3)
  output_1= Dense(1,activation="sigmoid",name='gender_out')(flatten)
  output_2= Dense(1,activation="relu",name='age_out')(flatten)
  
  model = Model(inputs=[inputs], outputs=[output_1,output_2])
  model.compile(loss=["binary_crossentropy","mae"], optimizer="Adam",
	metrics=["accuracy"])
  
  return model

# %%
Model=model((48,48,3))

# %%
Model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 48, 48, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 48, 48, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 48, 48, 32)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 48, 48, 32)   0           dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 32)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 48, 48, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 32)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 24, 24, 32)   0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 24, 64)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 24, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 24, 24, 64)   36928       dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 24, 24, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 64)   0           dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 24, 24, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 64)   0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 12, 12, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 12, 12, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 128)  0           dropout_8[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 12, 12, 128)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 12, 12, 128)  147584      dropout_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 12, 12, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 128)  0           dropout_10[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 12, 12, 128)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 128)    0           dropout_11[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4608)         0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# gender_out (Dense)              (None, 1)            4609        flatten[0][0]
# __________________________________________________________________________________________________
# age_out (Dense)                 (None, 1)            4609        flatten[0][0]
# ==================================================================================================
# Total params: 296,226
# Trainable params: 296,226
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Training

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow as tf

# %%
fle_s='Age_and_gender44.h5'
checkpointer = ModelCheckpoint(fle_s, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
History=Model.fit(X_train,Y_train_2,batch_size=64,validation_data=(X_test,Y_test_2),epochs=30,callbacks=[callback_list])
# Out:
# Epoch 1/30
# 278/278 [==============================] - 16s 28ms/step - loss: 19.2639 - gender_out_loss: 0.8315 - age_out_loss: 18.1169 - gender_out_accuracy: 0.5480 - age_out_accuracy: 0.0487 - val_loss: 28.3590 - val_gender_out_loss: 0.6792 - val_age_out_loss: 27.4452 - val_gender_out_accuracy: 0.5588 - val_age_out_accuracy: 0.0454
#
# Epoch 00001: val_loss improved from inf to 28.35901, saving model to Age_and_gender44.h5
# Epoch 2/30
# 278/278 [==============================] - 7s 25ms/step - loss: 15.6897 - gender_out_loss: 0.6719 - age_out_loss: 14.7925 - gender_out_accuracy: 0.6080 - age_out_accuracy: 0.0448 - val_loss: 25.9750 - val_gender_out_loss: 0.6425 - val_age_out_loss: 25.1249 - val_gender_out_accuracy: 0.6472 - val_age_out_accuracy: 0.0454
#
# Epoch 00002: val_loss improved from 28.35901 to 25.97504, saving model to Age_and_gender44.h5
# Epoch 3/30
# 278/278 [==============================] - 7s 25ms/step - loss: 14.4063 - gender_out_loss: 0.6413 - age_out_loss: 13.5597 - gender_out_accuracy: 0.6750 - age_out_accuracy: 0.0470 - val_loss: 24.0439 - val_gender_out_loss: 0.5969 - val_age_out_loss: 23.2425 - val_gender_out_accuracy: 0.7154 - val_age_out_accuracy: 0.0454
#
# Epoch 00003: val_loss improved from 25.97504 to 24.04392, saving model to Age_and_gender44.h5
# Epoch 4/30
# 278/278 [==============================] - 7s 25ms/step - loss: 13.1521 - gender_out_loss: 0.5759 - age_out_loss: 12.3675 - gender_out_accuracy: 0.7172 - age_out_accuracy: 0.0432 - val_loss: 22.3363 - val_gender_out_loss: 0.5484 - val_age_out_loss: 21.5636 - val_gender_out_accuracy: 0.7731 - val_age_out_accuracy: 0.0454
#
# Epoch 00004: val_loss improved from 24.04392 to 22.33635, saving model to Age_and_gender44.h5
# Epoch 5/30
# 278/278 [==============================] - 7s 25ms/step - loss: 12.2629 - gender_out_loss: 0.5300 - age_out_loss: 11.5026 - gender_out_accuracy: 0.7505 - age_out_accuracy: 0.0351 - val_loss: 20.4899 - val_gender_out_loss: 0.5237 - val_age_out_loss: 19.7220 - val_gender_out_accuracy: 0.7543 - val_age_out_accuracy: 0.0371
#
# Epoch 00005: val_loss improved from 22.33635 to 20.48991, saving model to Age_and_gender44.h5
# Epoch 6/30
# 278/278 [==============================] - 7s 25ms/step - loss: 11.8750 - gender_out_loss: 0.5093 - age_out_loss: 11.1169 - gender_out_accuracy: 0.7603 - age_out_accuracy: 0.0294 - val_loss: 21.2453 - val_gender_out_loss: 0.5197 - val_age_out_loss: 20.4659 - val_gender_out_accuracy: 0.8019 - val_age_out_accuracy: 0.0224
#
# Epoch 00006: val_loss did not improve from 20.48991
# Epoch 7/30
# 278/278 [==============================] - 7s 25ms/step - loss: 11.4810 - gender_out_loss: 0.4788 - age_out_loss: 10.7379 - gender_out_accuracy: 0.7756 - age_out_accuracy: 0.0234 - val_loss: 19.6270 - val_gender_out_loss: 0.5072 - val_age_out_loss: 18.8437 - val_gender_out_accuracy: 0.7869 - val_age_out_accuracy: 0.0143
#
# Epoch 00007: val_loss improved from 20.48991 to 19.62697, saving model to Age_and_gender44.h5
# Epoch 8/30
# 278/278 [==============================] - 7s 25ms/step - loss: 11.0830 - gender_out_loss: 0.4688 - age_out_loss: 10.3352 - gender_out_accuracy: 0.7847 - age_out_accuracy: 0.0181 - val_loss: 20.0419 - val_gender_out_loss: 0.4900 - val_age_out_loss: 19.2621 - val_gender_out_accuracy: 0.8245 - val_age_out_accuracy: 0.0123
#
# Epoch 00008: val_loss did not improve from 19.62697
# Epoch 9/30
# 278/278 [==============================] - 7s 25ms/step - loss: 10.7729 - gender_out_loss: 0.4546 - age_out_loss: 10.0254 - gender_out_accuracy: 0.7905 - age_out_accuracy: 0.0160 - val_loss: 20.4728 - val_gender_out_loss: 0.4828 - val_age_out_loss: 19.6872 - val_gender_out_accuracy: 0.8127 - val_age_out_accuracy: 0.0064
#
# Epoch 00009: val_loss did not improve from 19.62697
# Epoch 10/30
# 278/278 [==============================] - 7s 25ms/step - loss: 10.6331 - gender_out_loss: 0.4489 - age_out_loss: 9.8784 - gender_out_accuracy: 0.7925 - age_out_accuracy: 0.0137 - val_loss: 19.4564 - val_gender_out_loss: 0.4671 - val_age_out_loss: 18.6724 - val_gender_out_accuracy: 0.8183 - val_age_out_accuracy: 0.0089
#
# Epoch 00010: val_loss improved from 19.62697 to 19.45643, saving model to Age_and_gender44.h5
# Epoch 11/30
# 278/278 [==============================] - 7s 25ms/step - loss: 10.4423 - gender_out_loss: 0.4286 - age_out_loss: 9.6931 - gender_out_accuracy: 0.8083 - age_out_accuracy: 0.0126 - val_loss: 17.2508 - val_gender_out_loss: 0.4523 - val_age_out_loss: 16.4672 - val_gender_out_accuracy: 0.8200 - val_age_out_accuracy: 0.0118
#
# Epoch 00011: val_loss improved from 19.45643 to 17.25079, saving model to Age_and_gender44.h5
# Epoch 12/30
# 278/278 [==============================] - 7s 25ms/step - loss: 10.2143 - gender_out_loss: 0.4360 - age_out_loss: 9.4430 - gender_out_accuracy: 0.8055 - age_out_accuracy: 0.0118 - val_loss: 19.8172 - val_gender_out_loss: 0.4636 - val_age_out_loss: 19.0072 - val_gender_out_accuracy: 0.7898 - val_age_out_accuracy: 0.0064
#
# Epoch 00012: val_loss did not improve from 17.25079
# Epoch 13/30
# 278/278 [==============================] - 7s 25ms/step - loss: 10.2233 - gender_out_loss: 0.4430 - age_out_loss: 9.4304 - gender_out_accuracy: 0.8004 - age_out_accuracy: 0.0118 - val_loss: 17.8849 - val_gender_out_loss: 0.4458 - val_age_out_loss: 17.0804 - val_gender_out_accuracy: 0.8340 - val_age_out_accuracy: 0.0059
#
# Epoch 00013: val_loss did not improve from 17.25079
# Epoch 14/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.9564 - gender_out_loss: 0.4155 - age_out_loss: 9.1784 - gender_out_accuracy: 0.8169 - age_out_accuracy: 0.0096 - val_loss: 21.0893 - val_gender_out_loss: 0.4642 - val_age_out_loss: 20.2540 - val_gender_out_accuracy: 0.8019 - val_age_out_accuracy: 0.0035
#
# Epoch 00014: val_loss did not improve from 17.25079
# Epoch 15/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.9283 - gender_out_loss: 0.4165 - age_out_loss: 9.1382 - gender_out_accuracy: 0.8105 - age_out_accuracy: 0.0098 - val_loss: 18.1856 - val_gender_out_loss: 0.4471 - val_age_out_loss: 17.3583 - val_gender_out_accuracy: 0.7950 - val_age_out_accuracy: 0.0046
#
# Epoch 00015: val_loss did not improve from 17.25079
# Epoch 16/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.4898 - gender_out_loss: 0.4136 - age_out_loss: 8.6938 - gender_out_accuracy: 0.8111 - age_out_accuracy: 0.0092 - val_loss: 19.8387 - val_gender_out_loss: 0.4197 - val_age_out_loss: 19.0287 - val_gender_out_accuracy: 0.8406 - val_age_out_accuracy: 0.0030
#
# Epoch 00016: val_loss did not improve from 17.25079
# Epoch 17/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.3514 - gender_out_loss: 0.4027 - age_out_loss: 8.5562 - gender_out_accuracy: 0.8155 - age_out_accuracy: 0.0091 - val_loss: 18.5415 - val_gender_out_loss: 0.4214 - val_age_out_loss: 17.7185 - val_gender_out_accuracy: 0.8262 - val_age_out_accuracy: 0.0030
#
# Epoch 00017: val_loss did not improve from 17.25079
# Epoch 18/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.4515 - gender_out_loss: 0.4091 - age_out_loss: 8.6382 - gender_out_accuracy: 0.8167 - age_out_accuracy: 0.0090 - val_loss: 20.0230 - val_gender_out_loss: 0.4235 - val_age_out_loss: 19.1884 - val_gender_out_accuracy: 0.8367 - val_age_out_accuracy: 0.0025
#
# Epoch 00018: val_loss did not improve from 17.25079
# Epoch 19/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.2671 - gender_out_loss: 0.4120 - age_out_loss: 8.4414 - gender_out_accuracy: 0.8117 - age_out_accuracy: 0.0083 - val_loss: 17.8885 - val_gender_out_loss: 0.4126 - val_age_out_loss: 17.0563 - val_gender_out_accuracy: 0.8438 - val_age_out_accuracy: 0.0037
#
# Epoch 00019: val_loss did not improve from 17.25079
# Epoch 20/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.0949 - gender_out_loss: 0.3965 - age_out_loss: 8.2771 - gender_out_accuracy: 0.8210 - age_out_accuracy: 0.0078 - val_loss: 18.0259 - val_gender_out_loss: 0.4462 - val_age_out_loss: 17.1535 - val_gender_out_accuracy: 0.8061 - val_age_out_accuracy: 0.0035
#
# Epoch 00020: val_loss did not improve from 17.25079
# Epoch 21/30
# 278/278 [==============================] - 7s 25ms/step - loss: 9.2026 - gender_out_loss: 0.4049 - age_out_loss: 8.3683 - gender_out_accuracy: 0.8222 - age_out_accuracy: 0.0075 - val_loss: 18.9095 - val_gender_out_loss: 0.4288 - val_age_out_loss: 18.0446 - val_gender_out_accuracy: 0.8384 - val_age_out_accuracy: 0.0027
#
# Epoch 00021: val_loss did not improve from 17.25079
# Epoch 22/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.9953 - gender_out_loss: 0.4086 - age_out_loss: 8.1489 - gender_out_accuracy: 0.8192 - age_out_accuracy: 0.0072 - val_loss: 16.8762 - val_gender_out_loss: 0.4116 - val_age_out_loss: 16.0214 - val_gender_out_accuracy: 0.8542 - val_age_out_accuracy: 0.0049
#
# Epoch 00022: val_loss improved from 17.25079 to 16.87623, saving model to Age_and_gender44.h5
# Epoch 23/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.8309 - gender_out_loss: 0.3908 - age_out_loss: 7.9951 - gender_out_accuracy: 0.8276 - age_out_accuracy: 0.0076 - val_loss: 19.1104 - val_gender_out_loss: 0.4113 - val_age_out_loss: 18.2496 - val_gender_out_accuracy: 0.8338 - val_age_out_accuracy: 0.0025
#
# Epoch 00023: val_loss did not improve from 16.87623
# Epoch 24/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.7284 - gender_out_loss: 0.3943 - age_out_loss: 7.8833 - gender_out_accuracy: 0.8265 - age_out_accuracy: 0.0075 - val_loss: 18.2311 - val_gender_out_loss: 0.3951 - val_age_out_loss: 17.3794 - val_gender_out_accuracy: 0.8446 - val_age_out_accuracy: 0.0027
#
# Epoch 00024: val_loss did not improve from 16.87623
# Epoch 25/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.7637 - gender_out_loss: 0.3912 - age_out_loss: 7.9136 - gender_out_accuracy: 0.8243 - age_out_accuracy: 0.0070 - val_loss: 18.6888 - val_gender_out_loss: 0.4006 - val_age_out_loss: 17.8243 - val_gender_out_accuracy: 0.8537 - val_age_out_accuracy: 0.0027
#
# Epoch 00025: val_loss did not improve from 16.87623
# Epoch 26/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.6868 - gender_out_loss: 0.3842 - age_out_loss: 7.8368 - gender_out_accuracy: 0.8261 - age_out_accuracy: 0.0087 - val_loss: 19.2369 - val_gender_out_loss: 0.3955 - val_age_out_loss: 18.3706 - val_gender_out_accuracy: 0.8449 - val_age_out_accuracy: 0.0025
#
# Epoch 00026: val_loss did not improve from 16.87623
# Epoch 27/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.6881 - gender_out_loss: 0.3790 - age_out_loss: 7.8366 - gender_out_accuracy: 0.8303 - age_out_accuracy: 0.0073 - val_loss: 18.4689 - val_gender_out_loss: 0.4036 - val_age_out_loss: 17.5872 - val_gender_out_accuracy: 0.8471 - val_age_out_accuracy: 0.0027
#
# Epoch 00027: val_loss did not improve from 16.87623
# Epoch 28/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.6646 - gender_out_loss: 0.3918 - age_out_loss: 7.7930 - gender_out_accuracy: 0.8261 - age_out_accuracy: 0.0062 - val_loss: 18.7704 - val_gender_out_loss: 0.3982 - val_age_out_loss: 17.8872 - val_gender_out_accuracy: 0.8527 - val_age_out_accuracy: 0.0030
#
# Epoch 00028: val_loss did not improve from 16.87623
# Epoch 29/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.4441 - gender_out_loss: 0.3799 - age_out_loss: 7.5778 - gender_out_accuracy: 0.8291 - age_out_accuracy: 0.0076 - val_loss: 18.5255 - val_gender_out_loss: 0.3957 - val_age_out_loss: 17.6393 - val_gender_out_accuracy: 0.8557 - val_age_out_accuracy: 0.0029
#
# Epoch 00029: val_loss did not improve from 16.87623
# Epoch 30/30
# 278/278 [==============================] - 7s 25ms/step - loss: 8.5656 - gender_out_loss: 0.3821 - age_out_loss: 7.6916 - gender_out_accuracy: 0.8307 - age_out_accuracy: 0.0075 - val_loss: 16.9109 - val_gender_out_loss: 0.3808 - val_age_out_loss: 16.0349 - val_gender_out_accuracy: 0.8542 - val_age_out_accuracy: 0.0027
#
# Epoch 00030: val_loss did not improve from 16.87623

# %%
#ne radi
Model.save('age_and_gender_2.h5')

# %%
#drugi nacin za spremanje
saveModel='age_and_gender_22.h5'
checkpointer = ModelCheckpoint(saveModel, monitor='val_loss',verbose=1,save_best_only=True,save_weights_only=False, mode='auto',save_freq='epoch')
Early_stop=tf.keras.callbacks.EarlyStopping(patience=75, monitor='val_loss',restore_best_weights=True),
callback_list=[checkpointer,Early_stop]

# %%
end = time.time()
try:
  print(f"Runtime of the full program is {end - begin}")
except: pass

print(f"Runtime of the model training is {end - start}")
# Out:
# Runtime of the model training is 225.8324944972992

# %% [markdown]
# ### Evaluation

# %%
Model.evaluate(X_test,Y_test_2)
# Out:
# 186/186 [==============================] - 1s 4ms/step - loss: 16.9109 - gender_out_loss: 0.3808 - age_out_loss: 16.0349 - gender_out_accuracy: 0.8542 - age_out_accuracy: 0.0027
# [16.91092300415039,
#  0.38075384497642517,
#  16.03490447998047,
#  0.8542264103889465,
#  0.002699510660022497]

# %%
pred=Model.predict(X_test)

# %%
pred[1]
# Out:
# array([[ 0.      ],
#        [19.522097],
#        [17.4951  ],
#        ...,
#        [23.902874],
#        [13.176726],
#        [ 0.      ]], dtype=float32)

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For Gender

# %%
plt.plot(History.history['gender_out_accuracy'])
plt.plot(History.history['val_gender_out_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.subplots_adjust(top=1.00, bottom=0.0, left=0.0, right=0.95, hspace=0.25,
                        wspace=0.35)

# %% [markdown]
# ### For age

# %%
fig, ax = plt.subplots()
ax.scatter(Y_test_2[1], pred[1])
ax.plot([Y_test_2[1].min(),Y_test_2[1].max()], [Y_test_2[1].min(), Y_test_2[1].max()], 'k--', lw=4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %% [markdown]
# #### For Gender

# %%
i=0
Pred_l=[]
while(i<len(pred[0])):

  Pred_l.append(int(np.round(pred[0][i])))
  i+=1

# %%
from sklearn.metrics import confusion_matrix 

from sklearn.metrics import classification_report

# %%
report=classification_report(Y_test_2[0], Pred_l)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86      3068
#            1       0.87      0.82      0.84      2859
#
#     accuracy                           0.85      5927
#    macro avg       0.86      0.85      0.85      5927
# weighted avg       0.86      0.85      0.85      5927

# %%
results = confusion_matrix(Y_test_2[0], Pred_l)

# %%
from google.colab.patches import cv2_imshow
import cv2
def test_image(ind,images_f,images_f_2,Model):

  #pretvorba nazad u rgb format
  image = cv2.cvtColor(images_f[ind], cv2.COLOR_BGR2RGB)
  cv2_imshow(image)
  image_test=images_f_2[ind]

  #podaci iz slike i modela
  pred_1=Model.predict(np.array([image_test]))
  #print(pred_1)
  gender_f=['Male','Female']
  age=int(np.round(pred_1[1][0]))
  gender=int(np.round(pred_1[0][0]))

  print("Predicted Age: "+ str(age))
  print("Real Age: "+ str(ages_f[ind]))
  print("Predicted Gender: "+ gender_f[gender])
  print("Real Gender: "+ gender_f[genders_f[ind]])

# %%
test_image(57,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FD08204DD68>
# Predicted Age: 33
# Real Age: 80
# Predicted Gender: Male
# Real Gender: Female

# %%
test_image(137,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FD07A109A20>
# Predicted Age: 28
# Real Age: 83
# Predicted Gender: Male
# Real Gender: Female

# %%
test_image(502,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FD07A0E0BE0>
# Predicted Age: 0
# Real Age: 8
# Predicted Gender: Female
# Real Gender: Female

# %%
test_image(24,images_f,images_f_2,Model)
# Out:
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FD07A0C4048>
# Predicted Age: 36
# Real Age: 80
# Predicted Gender: Female
# Real Gender: Female
